# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Nicholas Rayden
# - **Email:** nicholasrayden@gmail.com

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apa saja faktor yang paling memengaruhi jumlah penyewaan sepeda per jam?
# - Bagaimana pola penyewaan sepeda berubah berdasarkan musim atau hari dalam seminggu?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# %matplotlib inline

# %% [markdown]
# ### Gathering Data

# %%
hour_df = pd.read_csv('C:/Users/Lenovo/Downloads/Bike Sharing Analysis/Bike Sharing Dataset/hour.csv')
day_df = pd.read_csv('C:/Users/Lenovo/Downloads/Bike Sharing Analysis/Bike Sharing Dataset/day.csv')

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# **Insight:**
# - Terdapat 17379 data pada dataset hour.csv dan 731 data pada dataset day.csv.
# - Kedua dataset ini mencakup data harian dan per jam selama dua tahun, yaitu tahun 2011 dan 2012.

# %% [markdown]
# ### Assessing Data

# %%
hour_df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
day_df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.465233    0.544894    0.183051    0.162961    0.142429    0.077498
# min      0.000000    1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      0.000000    1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      1.000000    2.000000    0.655417    0.608602    0.730209    0.233214
# max      1.000000    3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt
# count   731.000000   731.000000   731.000000
# mean    848.176471  3656.172367  4504.348837
# std     686.622488  1560.256377  1937.211452
# min       2.000000    20.000000    22.000000
# 25%     315.500000  2497.000000  3152.000000
# 50%     713.000000  3662.000000  4548.000000
# 75%    1096.000000  4776.500000  5956.000000
# max    3410.000000  6946.000000  8714.000000

# %% [markdown]
# **Insight:**
# - Tidak terdapat nilai kosong pada kedua dataset.
# - Terdapat beberapa fitur seperti temp, atemp, hum, dan windspeed yang merupakan variabel numerik.
# - Fitur season, holiday, weekday, dan workingday merupakan variabel kategorik yang bisa dieksplorasi lebih lanjut.

# %% [markdown]
# ### Cleaning Data

# %%
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

# %%
day_df['dteday'] = pd.to_datetime(day_df['dteday'])

# %% [markdown]
# **Insight:**
# - Data dteday berhasil diubah menjadi tipe datetime, sehingga bisa digunakan untuk analisis tren berdasarkan waktu.
# - Tidak ada nilai atau data yang perlu dibersihkan lebih lanjut karena dataset sudah bersih.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Seasonality and Hourly Trends

# %%
#Visualisasi jumlah penyewaan sepeda per jam:
plt.figure(figsize=(12, 6))
sns.histplot(hour_df['hr'], bins=24, kde=False)
plt.title('Distribution of Bike Rentals by Hour')
plt.xlabel('Hour of the Day')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Analisis distribusi untuk variabel numerikal dan kategorikal

# %%
# Distribusi variabel numerikal
numeric_columns = hour_df.select_dtypes(include=np.number).columns
hour_df[numeric_columns].hist(figsize=(12, 12), bins=20)
plt.suptitle('Univariate Analysis: Distribution of Numerical Features', size=16)
plt.show()

# Distribusi variabel kategorikal
categorical_columns = hour_df.select_dtypes(include=['category', 'object']).columns
for col in categorical_columns:
    plt.figure(figsize=(8, 4))
    sns.countplot(x=col, data=hour_df)
    plt.title(f'Distribution of {col}')
    plt.show()

# %% [markdown]
# ## Melakukan analisis hubungan antara dua variabel (kategorikal dan numerikal)

# %%
# Hubungan antara jumlah penyewaan dan temperatur
plt.figure(figsize=(8, 6))
sns.scatterplot(x='temp', y='cnt', data=hour_df)
plt.title('Bike Rentals vs Temperature')
plt.show()

# Hubungan antara jumlah penyewaan dan cuaca
plt.figure(figsize=(8, 6))
sns.boxplot(x='weathersit', y='cnt', data=hour_df)
plt.title('Bike Rentals vs Weather Situation')
plt.show()

# %% [markdown]
# ## Melihat korelasi antara beberapa variabel secara bersamaan

# %%
# Menggunakan Pairplot untuk melihat hubungan antar variabel
sns.pairplot(hour_df[['temp', 'hum', 'windspeed', 'cnt']])
plt.suptitle('Multivariate Analysis: Pairplot of Selected Numerical Features', size=16)
plt.show()

# %% [markdown]
# ## Menampilkan ringkasan statistik dari variabel-variabel yang relevan

# %%
# Analisis statistik ringkasan
print(hour_df[['temp', 'hum', 'windspeed', 'cnt']].describe())

# Analisis korelasi yang lebih dalam
corr_matrix = hour_df[['temp', 'hum', 'windspeed', 'cnt']].corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='Blues')
plt.title('Correlation Heatmap of Selected Features')
plt.show()
# Out:
#                temp           hum     windspeed           cnt
# count  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.496987      0.627229      0.190098    189.463088
# std        0.192556      0.192930      0.122340    181.387599
# min        0.020000      0.000000      0.000000      1.000000
# 25%        0.340000      0.480000      0.104500     40.000000
# 50%        0.500000      0.630000      0.194000    142.000000
# 75%        0.660000      0.780000      0.253700    281.000000
# max        1.000000      1.000000      0.850700    977.000000

# %% [markdown]
# ## Melihat hubungan antara variabel kategorikal dan numerikal

# %%
# Boxplot untuk menunjukkan distribusi penyewaan berdasarkan musim
plt.figure(figsize=(8, 6))
sns.boxplot(x='season', y='cnt', data=hour_df)
plt.title('Bike Rentals by Season')
plt.show()

# Boxplot untuk menunjukkan distribusi penyewaan berdasarkan hari kerja
plt.figure(figsize=(8, 6))
sns.boxplot(x='workingday', y='cnt', data=hour_df)
plt.title('Bike Rentals by Working Day')
plt.show()

# %% [markdown]
# **Insight:**
# - Penyewaan sepeda meningkat pada jam-jam sibuk (7-9 pagi dan 5-7 sore), yang sesuai dengan jam orang berangkat dan pulang kerja.
# - Musim panas cenderung memiliki jumlah penyewaan yang lebih tinggi dibandingkan musim lainnya.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Apa saja faktor yang paling memengaruhi jumlah penyewaan sepeda per jam?

# %%
numeric_df = hour_df.select_dtypes(include=[np.number])
corr_matrix = numeric_df.corr()

plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Insight: Fitur temp dan atemp menunjukkan korelasi yang cukup tinggi dengan cnt (jumlah penyewaan), yang mengindikasikan cuaca lebih hangat meningkatkan penyewaan sepeda.

# %% [markdown]
# ### Pertanyaan 2: Bagaimana pola penyewaan sepeda berubah berdasarkan musim atau hari dalam seminggu?

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='weekday', y='cnt', data=hour_df)
plt.title('Bike Rentals by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Count of Rentals')
plt.show()

# %%
#Visualisasi jumlah penyewaan berdasarkan musim:
plt.figure(figsize=(12, 6))
sns.countplot(x='season', data=hour_df)
plt.title('Distribution of Bike Rentals by Season')
plt.xlabel('Season')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Insight:**
# - Penyewaan sepeda memiliki pola musiman yang jelas, dengan jumlah penyewaan tertinggi di musim panas.
# - Ada peningkatan jumlah penyewaan pada jam sibuk di hari kerja, menunjukkan penggunaan sepeda sebagai alat transportasi harian.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
#RFM Analysis
latest_date = day_df['dteday'].max()
rfm = day_df.groupby('dteday').agg({
    'cnt': 'sum',       # Total penyewaan
    'casual': 'sum',    # Total penyewaan casual
    'registered': 'sum'  # Total penyewaan registered
}).reset_index()

# Menghitung Recency
recency_df = day_df[['dteday']].drop_duplicates()
recency_df['Recency'] = (latest_date - recency_df['dteday']).dt.days

# Menggabungkan Recency ke dalam rfm
rfm = rfm.merge(recency_df, on='dteday')
# Sekarang rfm memiliki 5 kolom: 'dteday', 'cnt', 'casual', 'registered', 'Recency'

# Renaming columns for clarity
rfm.columns = ['dteday', 'Frequency', 'Monetary', 'Registered', 'Recency']

# RFM Scoring
rfm['R_Score'] = pd.qcut(rfm['Recency'], 4, labels=[4, 3, 2, 1])
rfm['F_Score'] = pd.qcut(rfm['Frequency'], 4, labels=[1, 2, 3, 4])
rfm['M_Score'] = pd.qcut(rfm['Monetary'], 4, labels=[1, 2, 3, 4])
rfm['RFM_Score'] = rfm[['R_Score', 'F_Score', 'M_Score']].sum(axis=1)

print("RFM Analysis:\n", rfm.head())
# Out:
# RFM Analysis:
#        dteday  Frequency  Monetary  Registered  Recency R_Score F_Score  \
# 0 2011-01-01        985       331         654      730       1       1
# 1 2011-01-02        801       131         670      729       1       1
# 2 2011-01-03       1349       120        1229      728       1       1
# 3 2011-01-04       1562       108        1454      727       1       1
# 4 2011-01-05       1600        82        1518      726       1       1
#
#   M_Score  RFM_Score
# 0       2          4
# 1       1          3
# 2       1          3
# 3       1          3
# 4       1          3

# %%
# Membuat level penggunaan berdasarkan jam
hour_df['usage_level'] = pd.cut(hour_df['hr'], bins=[0, 6, 12, 18, 24], labels=['low', 'medium', 'high', 'very high'])

# Menghitung jumlah penyewaan berdasarkan tingkat penggunaan
usage_distribution = hour_df.groupby('usage_level')['cnt'].sum().reset_index()

# Menampilkan distribusi penggunaan
print(usage_distribution)
# Out:
#   usage_level      cnt
# 0         low   122511
# 1      medium  1036601
# 2        high  1418100
# 3   very high   676337
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9204\1877902037.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   usage_distribution = hour_df.groupby('usage_level')['cnt'].sum().reset_index()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclusion pertanyaan 1: Faktor yang paling memengaruhi jumlah penyewaan
# sepeda adalah cuaca (temperature dan apparent temperature) serta jam sibuk pada hari kerja.
# - Conclusion pertanyaan 2: Pola penyewaan sepeda bervariasi berdasarkan musim dan hari dalam seminggu, dengan penyewaan lebih tinggi pada jam sibuk di hari kerja dan musim panas.

# %% [markdown]
# **Menjalankan StreamLit**

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
hour_df = pd.read_csv('C:/Users/Lenovo/Downloads/Bike Sharing Analysis/Bike Sharing Dataset/hour.csv')

# Data Cleaning
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

# Sidebar filters
season = st.sidebar.selectbox('Select Season', sorted(hour_df['season'].unique()))
hour_range = st.sidebar.slider('Select Hour Range', 0, 23, (0, 23))

filtered_df = hour_df[(hour_df['season'] == season) & (hour_df['hr'].between(hour_range[0], hour_range[1]))]

# Title
st.title('Bike Sharing Analysis Dashboard')

# Data Information
st.header('Dataset Overview')
st.write('This dataset contains bike rental information per hour from 2011 to 2012.')
st.write(hour_df.head())
st.write(f'Total rows: {hour_df.shape[0]}, Total columns: {hour_df.shape[1]}')

### Univariate Analysis ###
st.header('Univariate Analysis')

# Histogram for numerical columns
st.subheader('Distribution of Numerical Features')
numeric_columns = hour_df.select_dtypes(include=np.number).columns
fig, ax = plt.subplots(figsize=(12, 12))
hour_df[numeric_columns].hist(ax=ax, bins=20)
st.pyplot(fig)

# Countplot for categorical columns
categorical_columns = hour_df.select_dtypes(include=['category', 'object']).columns
for col in categorical_columns:
    st.subheader(f'Distribution of {col}')
    fig, ax = plt.subplots()
    sns.countplot(x=col, data=hour_df, ax=ax)
    st.pyplot(fig)

### Bivariate Analysis ###
st.header('Bivariate Analysis')

# Scatterplot between temperature and bike rentals
st.subheader('Bike Rentals vs Temperature')
fig, ax = plt.subplots(figsize=(8, 6))
sns.scatterplot(x='temp', y='cnt', data=hour_df, ax=ax)
st.pyplot(fig)

# Boxplot for weather situation and bike rentals
st.subheader('Bike Rentals vs Weather Situation')
fig, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x='weathersit', y='cnt', data=hour_df, ax=ax)
st.pyplot(fig)

### Multivariate Analysis ###
st.header('Multivariate Analysis')

# Pairplot for numerical columns
st.subheader('Pairplot of Numerical Features')
selected_columns = ['temp', 'hum', 'windspeed', 'cnt']
fig = sns.pairplot(hour_df[selected_columns])
st.pyplot(fig)

### Statistical Analysis ###
st.header('Statistical Analysis')

# Display summary statistics
st.subheader('Summary Statistics of Numerical Features')
st.write(hour_df[selected_columns].describe())

# Correlation heatmap
st.subheader('Correlation Heatmap of Selected Features')
corr_matrix = hour_df[selected_columns].corr()
fig, ax = plt.subplots(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='Blues', ax=ax)
st.pyplot(fig)

### Categorical vs Numerical Analysis ###
st.header('Categorical vs Numerical Analysis')

# Boxplot for season vs bike rentals
st.subheader('Bike Rentals by Season')
fig, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x='season', y='cnt', data=hour_df, ax=ax)
st.pyplot(fig)

# Boxplot for working day vs bike rentals
st.subheader('Bike Rentals by Working Day')
fig, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x='workingday', y='cnt', data=hour_df, ax=ax)
st.pyplot(fig)

# Conclusion
st.header('Conclusion')
st.write("""
The most important factors affecting bike rentals are temperature, weather situation, and peak hours during weekdays.
The analysis also shows a significant relationship between season, working days, and the number of bike rentals.
""")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9204\1439696254.py:34: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   hour_df[numeric_columns].hist(ax=ax, bins=20)
